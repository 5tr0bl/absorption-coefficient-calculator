# %%
import utils
import numpy as np

freq_range = np.arange(1, 20000, step=1)
ran_alphas = np.random.rand(len(freq_range))
x_label = "x"
y_label = "y"
title = "title"

# %%
utils.plotly_go_line(freq_range, ran_alphas, x_label, y_label, title)

# %%
utils.plotly_freq_bands(freq_range, ran_alphas, x_label, y_label, title, 'third')
